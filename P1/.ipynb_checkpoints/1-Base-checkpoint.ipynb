# %%
import pandas as pd
import missingno as mno
import xgboost as xgb
import seaborn as sns
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics,svm
from sklearn.model_selection import train_test_split,GridSearchCV, RandomizedSearchCV
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score,classification_report,confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score,precision_recall_curve
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
import numpy as np
from sklearn import tree,preprocessing 
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.model_selection import learning_curve
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.decomposition import *
from sklearn.preprocessing import *
import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# %%
df_train
# Out:
#           CustomerId TransactionStartTime   Value  Amount       TransactionId  \
# 0      CustomerId_27      9/21/2018 12:17   550.0  -550.0  TransactionId_1683
# 1      CustomerId_27       9/25/2018 9:20   550.0  -550.0  TransactionId_2235
# 2      CustomerId_27      9/25/2018 10:33   550.0  -550.0  TransactionId_1053
# 3      CustomerId_27      9/27/2018 10:26  1000.0 -1000.0  TransactionId_2633
# 4      CustomerId_27      9/27/2018 12:44   500.0  -500.0    TransactionId_71
# ...              ...                  ...     ...     ...                 ...
# 2095   CustomerId_28      3/30/2019 21:55  2000.0 -2000.0  TransactionId_1185
# 2096   CustomerId_28      3/30/2019 23:54  5000.0 -5000.0  TransactionId_1824
# 2097   CustomerId_34       3/31/2019 5:40  5000.0 -5000.0  TransactionId_2507
# 2098  CustomerId_346       3/31/2019 9:37  1500.0 -1500.0   TransactionId_540
# 2099  CustomerId_188      3/31/2019 12:16  1000.0 -1000.0  TransactionId_1889
#
#            BatchId    SubscriptionId CurrencyCode  CountryCode    ProviderId  \
# 0      BatchId_641  SubscriptionId_2          UGX          256  ProviderId_1
# 1      BatchId_820  SubscriptionId_2          UGX          256  ProviderId_1
# 2      BatchId_210  SubscriptionId_4          UGX          256  ProviderId_1
# 3      BatchId_876  SubscriptionId_4          UGX          256  ProviderId_1
# 4     BatchId_1362  SubscriptionId_4          UGX          256  ProviderId_1
# ...            ...               ...          ...          ...           ...
# 2095  BatchId_2069  SubscriptionId_7          UGX          256  ProviderId_1
# 2096  BatchId_1552  SubscriptionId_7          UGX          256  ProviderId_1
# 2097  BatchId_1093  SubscriptionId_7          UGX          256  ProviderId_1
# 2098  BatchId_1239  SubscriptionId_7          UGX          256  ProviderId_1
# 2099   BatchId_355  SubscriptionId_7          UGX          256  ProviderId_1
#
#       ...       LoanId       PaidOnDate IsFinalPayBack    InvestorId  \
# 0     ...          NaN              NaN            NaN           NaN
# 1     ...          NaN              NaN            NaN           NaN
# 2     ...          NaN              NaN            NaN           NaN
# 3     ...          NaN              NaN            NaN           NaN
# 4     ...          NaN              NaN            NaN           NaN
# ...   ...          ...              ...            ...           ...
# 2095  ...   LoanId_293  4/29/2019 14:35            1.0  InvestorId_1
# 2096  ...  LoanId_1040  4/29/2019 14:32            1.0  InvestorId_1
# 2097  ...  LoanId_1585   6/15/2019 6:20            1.0  InvestorId_1
# 2098  ...  LoanId_1314  4/23/2019 15:44            1.0  InvestorId_1
# 2099  ...  LoanId_1570  4/10/2019 17:33            1.0  InvestorId_1
#
#               DueDate       LoanApplicationId       PayBackId  \
# 0                 NaN                     NaN             NaN
# 1                 NaN                     NaN             NaN
# 2                 NaN                     NaN             NaN
# 3                 NaN                     NaN             NaN
# 4                 NaN                     NaN             NaN
# ...               ...                     ...             ...
# 2095  4/29/2019 21:55   LoanApplicationId_524  PayBackId_1106
# 2096  4/29/2019 23:53  LoanApplicationId_1441   PayBackId_966
# 2097   4/30/2019 5:40  LoanApplicationId_1466  PayBackId_1271
# 2098   4/30/2019 9:37  LoanApplicationId_1389   PayBackId_945
# 2099  4/30/2019 12:16    LoanApplicationId_57   PayBackId_830
#
#            ThirdPartyId IsThirdPartyConfirmed  IsDefaulted
# 0                   NaN                   NaN          NaN
# 1                   NaN                   NaN          NaN
# 2                   NaN                   NaN          NaN
# 3                   NaN                   NaN          NaN
# 4                   NaN                   NaN          NaN
# ...                 ...                   ...          ...
# 2095   ThirdPartyId_857                   1.0          0.0
# 2096   ThirdPartyId_958                   1.0          0.0
# 2097  ThirdPartyId_1981                   1.0          0.0
# 2098   ThirdPartyId_705                   1.0          0.0
# 2099   ThirdPartyId_899                   1.0          0.0
#
# [2100 rows x 27 columns]

# %%
df_test
# Out:
#          CustomerId TransactionStartTime    Value   Amount  \
# 0    CustomerId_310      3/31/2019 13:33  14000.0 -14000.0
# 1    CustomerId_243      3/31/2019 15:04   1000.0  -1000.0
# 2    CustomerId_142      3/31/2019 17:31   2500.0  -2500.0
# 3    CustomerId_142      3/31/2019 17:32    500.0   -500.0
# 4    CustomerId_142      3/31/2019 17:34   1000.0  -1000.0
# ..              ...                  ...      ...      ...
# 900  CustomerId_412       7/16/2019 0:18    500.0   -500.0
# 901  CustomerId_326       7/16/2019 3:17   1000.0  -1000.0
# 902  CustomerId_497      7/16/2019 15:06   1000.0  -1000.0
# 903  CustomerId_497      7/16/2019 15:09    800.0   -800.0
# 904  CustomerId_372       7/17/2019 5:34   1900.0  -1900.0
#
#           TransactionId       BatchId    SubscriptionId CurrencyCode  \
# 0     TransactionId_925  BatchId_1144  SubscriptionId_7          UGX
# 1    TransactionId_1080  BatchId_1214  SubscriptionId_7          UGX
# 2    TransactionId_2315  BatchId_2150  SubscriptionId_7          UGX
# 3    TransactionId_1466  BatchId_1071  SubscriptionId_7          UGX
# 4     TransactionId_337  BatchId_2477  SubscriptionId_7          UGX
# ..                  ...           ...               ...          ...
# 900   TransactionId_680  BatchId_2079  SubscriptionId_7          UGX
# 901  TransactionId_2504  BatchId_1432  SubscriptionId_7          UGX
# 902   TransactionId_995  BatchId_1410  SubscriptionId_7          UGX
# 903   TransactionId_708  BatchId_1343  SubscriptionId_7          UGX
# 904   TransactionId_585   BatchId_665  SubscriptionId_7          UGX
#
#      CountryCode    ProviderId    ProductId ProductCategory    ChannelId  \
# 0            256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# 1            256  ProviderId_1  ProductId_8    data_bundles  ChannelId_1
# 2            256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# 3            256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# 4            256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# ..           ...           ...          ...             ...          ...
# 900          256  ProviderId_1  ProductId_1         airtime  ChannelId_1
# 901          256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# 902          256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# 903          256  ProviderId_1  ProductId_3         airtime  ChannelId_1
# 904          256  ProviderId_1  ProductId_7         airtime  ChannelId_1
#
#      TransactionStatus   IssuedDateLoan       LoanId    InvestorId  \
# 0                    1  3/31/2019 13:33  LoanId_1027  InvestorId_1
# 1                    1  3/31/2019 15:04   LoanId_768  InvestorId_1
# 2                    1  3/31/2019 17:31  LoanId_1067  InvestorId_1
# 3                    1  3/31/2019 17:32   LoanId_202  InvestorId_1
# 4                    1  3/31/2019 17:34   LoanId_533  InvestorId_1
# ..                 ...              ...          ...           ...
# 900                  0              NaN          NaN           NaN
# 901                  0              NaN          NaN           NaN
# 902                  0              NaN          NaN           NaN
# 903                  0              NaN          NaN           NaN
# 904                  0              NaN          NaN           NaN
#
#           LoanApplicationId       ThirdPartyId
# 0     LoanApplicationId_825  ThirdPartyId_1175
# 1      LoanApplicationId_68   ThirdPartyId_604
# 2    LoanApplicationId_1223  ThirdPartyId_1521
# 3     LoanApplicationId_633   ThirdPartyId_406
# 4     LoanApplicationId_309   ThirdPartyId_302
# ..                      ...                ...
# 900                     NaN                NaN
# 901                     NaN                NaN
# 902                     NaN                NaN
# 903                     NaN                NaN
# 904                     NaN                NaN
#
# [905 rows x 19 columns]

# %%
df_train.isnull().sum()
# Out:
# CustomerId                 0
# TransactionStartTime       0
# Value                      0
# Amount                     0
# TransactionId              0
# BatchId                    0
# SubscriptionId             0
# CurrencyCode               0
# CountryCode                0
# ProviderId                 0
# ProductId                  0
# ProductCategory            0
# ChannelId                  0
# TransactionStatus          0
# IssuedDateLoan           612
# AmountLoan               612
# Currency                 612
# LoanId                   612
# PaidOnDate               612
# IsFinalPayBack           612
# InvestorId               612
# DueDate                  614
# LoanApplicationId        617
# PayBackId                612
# ThirdPartyId             614
# IsThirdPartyConfirmed    612
# IsDefaulted              612
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2100 entries, 0 to 2099
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CustomerId             2100 non-null   object
#  1   TransactionStartTime   2100 non-null   object
#  2   Value                  2100 non-null   float64
#  3   Amount                 2100 non-null   float64
#  4   TransactionId          2100 non-null   object
#  5   BatchId                2100 non-null   object
#  6   SubscriptionId         2100 non-null   object
#  7   CurrencyCode           2100 non-null   object
#  8   CountryCode            2100 non-null   int64
#  9   ProviderId             2100 non-null   object
#  10  ProductId              2100 non-null   object
#  11  ProductCategory        2100 non-null   object
#  12  ChannelId              2100 non-null   object
#  13  TransactionStatus      2100 non-null   int64
#  14  IssuedDateLoan         1488 non-null   object
#  15  AmountLoan             1488 non-null   float64
#  16  Currency               1488 non-null   object
#  17  LoanId                 1488 non-null   object
#  18  PaidOnDate             1488 non-null   object
#  19  IsFinalPayBack         1488 non-null   float64
#  20  InvestorId             1488 non-null   object
#  21  DueDate                1486 non-null   object
#  22  LoanApplicationId      1483 non-null   object
#  23  PayBackId              1488 non-null   object
#  24  ThirdPartyId           1486 non-null   object
#  25  IsThirdPartyConfirmed  1488 non-null   float64
#  26  IsDefaulted            1488 non-null   float64
# dtypes: float64(6), int64(2), object(19)
# memory usage: 443.1+ KB

# %%
df_test.isnull().sum()
# Out:
# CustomerId                0
# TransactionStartTime      0
# Value                     0
# Amount                    0
# TransactionId             0
# BatchId                   0
# SubscriptionId            0
# CurrencyCode              0
# CountryCode               0
# ProviderId                0
# ProductId                 0
# ProductCategory           0
# ChannelId                 0
# TransactionStatus         0
# IssuedDateLoan          427
# LoanId                  427
# InvestorId              427
# LoanApplicationId       427
# ThirdPartyId            427
# dtype: int64

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 905 entries, 0 to 904
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerId            905 non-null    object
#  1   TransactionStartTime  905 non-null    object
#  2   Value                 905 non-null    float64
#  3   Amount                905 non-null    float64
#  4   TransactionId         905 non-null    object
#  5   BatchId               905 non-null    object
#  6   SubscriptionId        905 non-null    object
#  7   CurrencyCode          905 non-null    object
#  8   CountryCode           905 non-null    int64
#  9   ProviderId            905 non-null    object
#  10  ProductId             905 non-null    object
#  11  ProductCategory       905 non-null    object
#  12  ChannelId             905 non-null    object
#  13  TransactionStatus     905 non-null    int64
#  14  IssuedDateLoan        478 non-null    object
#  15  LoanId                478 non-null    object
#  16  InvestorId            478 non-null    object
#  17  LoanApplicationId     478 non-null    object
#  18  ThirdPartyId          478 non-null    object
# dtypes: float64(2), int64(2), object(15)
# memory usage: 134.5+ KB

# %%
list(set(df_train.columns) - set(df_test.columns))
# Out:
# ['IsFinalPayBack',
#  'PaidOnDate',
#  'IsThirdPartyConfirmed',
#  'PayBackId',
#  'DueDate',
#  'Currency',
#  'AmountLoan',
#  'IsDefaulted']

# %%
df_sameid = df_train[df_train["CustomerId" ]== 'CustomerId_27']

# %%
df_sameid = df_train[df_train["CustomerId" ].isin(df_test['CustomerId'])]

# %%
df_sameid
# Out:
#           CustomerId TransactionStartTime   Value  Amount       TransactionId  \
# 0      CustomerId_27      9/21/2018 12:17   550.0  -550.0  TransactionId_1683
# 1      CustomerId_27       9/25/2018 9:20   550.0  -550.0  TransactionId_2235
# 2      CustomerId_27      9/25/2018 10:33   550.0  -550.0  TransactionId_1053
# 3      CustomerId_27      9/27/2018 10:26  1000.0 -1000.0  TransactionId_2633
# 4      CustomerId_27      9/27/2018 12:44   500.0  -500.0    TransactionId_71
# ...              ...                  ...     ...     ...                 ...
# 2095   CustomerId_28      3/30/2019 21:55  2000.0 -2000.0  TransactionId_1185
# 2096   CustomerId_28      3/30/2019 23:54  5000.0 -5000.0  TransactionId_1824
# 2097   CustomerId_34       3/31/2019 5:40  5000.0 -5000.0  TransactionId_2507
# 2098  CustomerId_346       3/31/2019 9:37  1500.0 -1500.0   TransactionId_540
# 2099  CustomerId_188      3/31/2019 12:16  1000.0 -1000.0  TransactionId_1889
#
#            BatchId    SubscriptionId CurrencyCode  CountryCode    ProviderId  \
# 0      BatchId_641  SubscriptionId_2          UGX          256  ProviderId_1
# 1      BatchId_820  SubscriptionId_2          UGX          256  ProviderId_1
# 2      BatchId_210  SubscriptionId_4          UGX          256  ProviderId_1
# 3      BatchId_876  SubscriptionId_4          UGX          256  ProviderId_1
# 4     BatchId_1362  SubscriptionId_4          UGX          256  ProviderId_1
# ...            ...               ...          ...          ...           ...
# 2095  BatchId_2069  SubscriptionId_7          UGX          256  ProviderId_1
# 2096  BatchId_1552  SubscriptionId_7          UGX          256  ProviderId_1
# 2097  BatchId_1093  SubscriptionId_7          UGX          256  ProviderId_1
# 2098  BatchId_1239  SubscriptionId_7          UGX          256  ProviderId_1
# 2099   BatchId_355  SubscriptionId_7          UGX          256  ProviderId_1
#
#       ...       LoanId       PaidOnDate IsFinalPayBack    InvestorId  \
# 0     ...          NaN              NaN            NaN           NaN
# 1     ...          NaN              NaN            NaN           NaN
# 2     ...          NaN              NaN            NaN           NaN
# 3     ...          NaN              NaN            NaN           NaN
# 4     ...          NaN              NaN            NaN           NaN
# ...   ...          ...              ...            ...           ...
# 2095  ...   LoanId_293  4/29/2019 14:35            1.0  InvestorId_1
# 2096  ...  LoanId_1040  4/29/2019 14:32            1.0  InvestorId_1
# 2097  ...  LoanId_1585   6/15/2019 6:20            1.0  InvestorId_1
# 2098  ...  LoanId_1314  4/23/2019 15:44            1.0  InvestorId_1
# 2099  ...  LoanId_1570  4/10/2019 17:33            1.0  InvestorId_1
#
#               DueDate       LoanApplicationId       PayBackId  \
# 0                 NaN                     NaN             NaN
# 1                 NaN                     NaN             NaN
# 2                 NaN                     NaN             NaN
# 3                 NaN                     NaN             NaN
# 4                 NaN                     NaN             NaN
# ...               ...                     ...             ...
# 2095  4/29/2019 21:55   LoanApplicationId_524  PayBackId_1106
# 2096  4/29/2019 23:53  LoanApplicationId_1441   PayBackId_966
# 2097   4/30/2019 5:40  LoanApplicationId_1466  PayBackId_1271
# 2098   4/30/2019 9:37  LoanApplicationId_1389   PayBackId_945
# 2099  4/30/2019 12:16    LoanApplicationId_57   PayBackId_830
#
#            ThirdPartyId IsThirdPartyConfirmed  IsDefaulted
# 0                   NaN                   NaN          NaN
# 1                   NaN                   NaN          NaN
# 2                   NaN                   NaN          NaN
# 3                   NaN                   NaN          NaN
# 4                   NaN                   NaN          NaN
# ...                 ...                   ...          ...
# 2095   ThirdPartyId_857                   1.0          0.0
# 2096   ThirdPartyId_958                   1.0          0.0
# 2097  ThirdPartyId_1981                   1.0          0.0
# 2098   ThirdPartyId_705                   1.0          0.0
# 2099   ThirdPartyId_899                   1.0          0.0
#
# [950 rows x 27 columns]

# %%
df_cos27 = df_train[df_train["CustomerId" ]== 'CustomerId_27']

# %%
df_cos27
# Out:
#          CustomerId TransactionStartTime    Value   Amount  \
# 0     CustomerId_27      9/21/2018 12:17    550.0   -550.0
# 1     CustomerId_27       9/25/2018 9:20    550.0   -550.0
# 2     CustomerId_27      9/25/2018 10:33    550.0   -550.0
# 3     CustomerId_27      9/27/2018 10:26   1000.0  -1000.0
# 4     CustomerId_27      9/27/2018 12:44    500.0   -500.0
# 5     CustomerId_27      9/28/2018 12:40    500.0   -500.0
# 6     CustomerId_27       10/3/2018 9:34    500.0   -500.0
# 7     CustomerId_27      10/17/2018 9:06   1235.0  -1235.0
# 8     CustomerId_27     10/17/2018 12:02   1235.0  -1235.0
# 12    CustomerId_27      10/19/2018 9:51   1030.0  -1030.0
# 16    CustomerId_27     10/22/2018 17:24   1000.0  -1000.0
# 18    CustomerId_27     10/23/2018 15:20   1000.0  -1000.0
# 19    CustomerId_27     10/23/2018 15:31    500.0   -500.0
# 20    CustomerId_27      10/24/2018 6:56    500.0   -500.0
# 21    CustomerId_27      10/24/2018 9:14    500.0   -500.0
# 29    CustomerId_27     10/30/2018 10:25    500.0   -500.0
# 170   CustomerId_27     11/27/2018 18:12   1500.0  -1500.0
# 171   CustomerId_27     11/27/2018 18:14   2000.0  -2000.0
# 175   CustomerId_27     11/27/2018 19:11  11000.0 -11000.0
# 176   CustomerId_27     11/27/2018 19:11  11000.0 -11000.0
# 177   CustomerId_27     11/27/2018 19:11  11000.0 -11000.0
# 212   CustomerId_27     11/30/2018 10:07  10000.0 -10000.0
# 213   CustomerId_27     11/30/2018 10:07  10000.0 -10000.0
# 274   CustomerId_27       12/5/2018 9:37   1000.0  -1000.0
# 275   CustomerId_27       12/5/2018 9:37   1000.0  -1000.0
# 1214  CustomerId_27      2/15/2019 11:16    100.0   -100.0
#
#            TransactionId       BatchId    SubscriptionId CurrencyCode  \
# 0     TransactionId_1683   BatchId_641  SubscriptionId_2          UGX
# 1     TransactionId_2235   BatchId_820  SubscriptionId_2          UGX
# 2     TransactionId_1053   BatchId_210  SubscriptionId_4          UGX
# 3     TransactionId_2633   BatchId_876  SubscriptionId_4          UGX
# 4       TransactionId_71  BatchId_1362  SubscriptionId_4          UGX
# 5      TransactionId_930   BatchId_357  SubscriptionId_4          UGX
# 6     TransactionId_1381     BatchId_8  SubscriptionId_4          UGX
# 7      TransactionId_255  BatchId_1082  SubscriptionId_4          UGX
# 8      TransactionId_543  BatchId_1195  SubscriptionId_4          UGX
# 12     TransactionId_379  BatchId_2253  SubscriptionId_4          UGX
# 16    TransactionId_2209  BatchId_2078  SubscriptionId_4          UGX
# 18    TransactionId_1367  BatchId_1675  SubscriptionId_1          UGX
# 19     TransactionId_871  BatchId_2449  SubscriptionId_1          UGX
# 20    TransactionId_1019  BatchId_1564  SubscriptionId_1          UGX
# 21     TransactionId_749    BatchId_86  SubscriptionId_1          UGX
# 29    TransactionId_1569   BatchId_846  SubscriptionId_1          UGX
# 170   TransactionId_1978   BatchId_884  SubscriptionId_1          UGX
# 171      TransactionId_1  BatchId_2269  SubscriptionId_1          UGX
# 175   TransactionId_2022  BatchId_2147  SubscriptionId_1          UGX
# 176   TransactionId_2022  BatchId_2147  SubscriptionId_1          UGX
# 177   TransactionId_2022  BatchId_2147  SubscriptionId_1          UGX
# 212   TransactionId_2259  BatchId_1389  SubscriptionId_1          UGX
# 213   TransactionId_2259  BatchId_1389  SubscriptionId_1          UGX
# 274   TransactionId_1180  BatchId_2095  SubscriptionId_1          UGX
# 275   TransactionId_1180  BatchId_2095  SubscriptionId_1          UGX
# 1214  TransactionId_1173  BatchId_2546  SubscriptionId_1          UGX
#
#       CountryCode    ProviderId  ...       LoanId        PaidOnDate  \
# 0             256  ProviderId_1  ...          NaN               NaN
# 1             256  ProviderId_1  ...          NaN               NaN
# 2             256  ProviderId_1  ...          NaN               NaN
# 3             256  ProviderId_1  ...          NaN               NaN
# 4             256  ProviderId_1  ...          NaN               NaN
# 5             256  ProviderId_1  ...          NaN               NaN
# 6             256  ProviderId_1  ...          NaN               NaN
# 7             256  ProviderId_1  ...          NaN               NaN
# 8             256  ProviderId_1  ...          NaN               NaN
# 12            256  ProviderId_1  ...          NaN               NaN
# 16            256  ProviderId_1  ...          NaN               NaN
# 18            256  ProviderId_1  ...  LoanId_1438  10/23/2018 15:26
# 19            256  ProviderId_1  ...  LoanId_1304   10/24/2018 6:38
# 20            256  ProviderId_1  ...  LoanId_1436   10/24/2018 7:01
# 21            256  ProviderId_1  ...          NaN               NaN
# 29            256  ProviderId_1  ...   LoanId_240  10/30/2018 10:54
# 170           256  ProviderId_1  ...   LoanId_762  11/30/2018 18:10
# 171           256  ProviderId_1  ...   LoanId_562  11/29/2018 14:11
# 175           256  ProviderId_1  ...   LoanId_966    1/18/2019 8:40
# 176           256  ProviderId_1  ...   LoanId_966    1/18/2019 8:41
# 177           256  ProviderId_1  ...   LoanId_966    2/1/2019 13:52
# 212           256  ProviderId_1  ...   LoanId_963    12/5/2018 9:33
# 213           256  ProviderId_1  ...   LoanId_963    2/1/2019 13:34
# 274           256  ProviderId_1  ...  LoanId_1064    12/5/2018 9:44
# 275           256  ProviderId_1  ...  LoanId_1064    2/1/2019 13:53
# 1214          256  ProviderId_1  ...   LoanId_134   2/15/2019 11:26
#
#      IsFinalPayBack    InvestorId           DueDate       LoanApplicationId  \
# 0               NaN           NaN               NaN                     NaN
# 1               NaN           NaN               NaN                     NaN
# 2               NaN           NaN               NaN                     NaN
# 3               NaN           NaN               NaN                     NaN
# 4               NaN           NaN               NaN                     NaN
# 5               NaN           NaN               NaN                     NaN
# 6               NaN           NaN               NaN                     NaN
# 7               NaN           NaN               NaN                     NaN
# 8               NaN           NaN               NaN                     NaN
# 12              NaN           NaN               NaN                     NaN
# 16              NaN           NaN               NaN                     NaN
# 18              1.0  InvestorId_2  11/22/2018 15:20  LoanApplicationId_1171
# 19              1.0  InvestorId_2   11/23/2018 6:33   LoanApplicationId_702
# 20              1.0  InvestorId_2   11/23/2018 6:55   LoanApplicationId_508
# 21              NaN           NaN               NaN                     NaN
# 29              1.0  InvestorId_2  11/29/2018 10:25   LoanApplicationId_641
# 170             1.0  InvestorId_2  12/27/2018 18:12   LoanApplicationId_322
# 171             1.0  InvestorId_2  12/27/2018 18:14    LoanApplicationId_91
# 175             0.0  InvestorId_2  12/27/2018 19:11  LoanApplicationId_1297
# 176             0.0  InvestorId_2  12/27/2018 19:11  LoanApplicationId_1297
# 177             1.0  InvestorId_2  12/27/2018 19:11  LoanApplicationId_1297
# 212             0.0  InvestorId_2  12/30/2018 10:07  LoanApplicationId_1159
# 213             1.0  InvestorId_2  12/30/2018 10:07  LoanApplicationId_1159
# 274             0.0  InvestorId_2     1/4/2019 9:37   LoanApplicationId_778
# 275             1.0  InvestorId_2     1/4/2019 9:37   LoanApplicationId_778
# 1214            1.0  InvestorId_2   3/17/2019 11:16   LoanApplicationId_629
#
#            PayBackId       ThirdPartyId IsThirdPartyConfirmed  IsDefaulted
# 0                NaN                NaN                   NaN          NaN
# 1                NaN                NaN                   NaN          NaN
# 2                NaN                NaN                   NaN          NaN
# 3                NaN                NaN                   NaN          NaN
# 4                NaN                NaN                   NaN          NaN
# 5                NaN                NaN                   NaN          NaN
# 6                NaN                NaN                   NaN          NaN
# 7                NaN                NaN                   NaN          NaN
# 8                NaN                NaN                   NaN          NaN
# 12               NaN                NaN                   NaN          NaN
# 16               NaN                NaN                   NaN          NaN
# 18    PayBackId_1085  ThirdPartyId_1265                   0.0          0.0
# 19     PayBackId_763  ThirdPartyId_1962                   0.0          0.0
# 20    PayBackId_1228  ThirdPartyId_2008                   0.0          0.0
# 21               NaN                NaN                   NaN          NaN
# 29    PayBackId_1478  ThirdPartyId_2014                   1.0          0.0
# 170   PayBackId_1536  ThirdPartyId_1903                   1.0          0.0
# 171   PayBackId_1623  ThirdPartyId_1882                   1.0          0.0
# 175    PayBackId_796  ThirdPartyId_1718                   1.0          0.0
# 176    PayBackId_506  ThirdPartyId_1672                   1.0          0.0
# 177    PayBackId_433   ThirdPartyId_116                   1.0          0.0
# 212    PayBackId_417  ThirdPartyId_1355                   1.0          0.0
# 213    PayBackId_404  ThirdPartyId_1079                   1.0          0.0
# 274     PayBackId_93     ThirdPartyId_3                   1.0          0.0
# 275    PayBackId_249   ThirdPartyId_356                   1.0          0.0
# 1214   PayBackId_649  ThirdPartyId_1136                   1.0          0.0
#
# [26 rows x 27 columns]

# %%
df_train
# Out:
#           CustomerId TransactionStartTime   Value  Amount       TransactionId  \
# 0      CustomerId_27      9/21/2018 12:17   550.0  -550.0  TransactionId_1683
# 1      CustomerId_27       9/25/2018 9:20   550.0  -550.0  TransactionId_2235
# 2      CustomerId_27      9/25/2018 10:33   550.0  -550.0  TransactionId_1053
# 3      CustomerId_27      9/27/2018 10:26  1000.0 -1000.0  TransactionId_2633
# 4      CustomerId_27      9/27/2018 12:44   500.0  -500.0    TransactionId_71
# ...              ...                  ...     ...     ...                 ...
# 2095   CustomerId_28      3/30/2019 21:55  2000.0 -2000.0  TransactionId_1185
# 2096   CustomerId_28      3/30/2019 23:54  5000.0 -5000.0  TransactionId_1824
# 2097   CustomerId_34       3/31/2019 5:40  5000.0 -5000.0  TransactionId_2507
# 2098  CustomerId_346       3/31/2019 9:37  1500.0 -1500.0   TransactionId_540
# 2099  CustomerId_188      3/31/2019 12:16  1000.0 -1000.0  TransactionId_1889
#
#            BatchId    SubscriptionId CurrencyCode  CountryCode    ProviderId  \
# 0      BatchId_641  SubscriptionId_2          UGX          256  ProviderId_1
# 1      BatchId_820  SubscriptionId_2          UGX          256  ProviderId_1
# 2      BatchId_210  SubscriptionId_4          UGX          256  ProviderId_1
# 3      BatchId_876  SubscriptionId_4          UGX          256  ProviderId_1
# 4     BatchId_1362  SubscriptionId_4          UGX          256  ProviderId_1
# ...            ...               ...          ...          ...           ...
# 2095  BatchId_2069  SubscriptionId_7          UGX          256  ProviderId_1
# 2096  BatchId_1552  SubscriptionId_7          UGX          256  ProviderId_1
# 2097  BatchId_1093  SubscriptionId_7          UGX          256  ProviderId_1
# 2098  BatchId_1239  SubscriptionId_7          UGX          256  ProviderId_1
# 2099   BatchId_355  SubscriptionId_7          UGX          256  ProviderId_1
#
#       ...       LoanId       PaidOnDate IsFinalPayBack    InvestorId  \
# 0     ...          NaN              NaN            NaN           NaN
# 1     ...          NaN              NaN            NaN           NaN
# 2     ...          NaN              NaN            NaN           NaN
# 3     ...          NaN              NaN            NaN           NaN
# 4     ...          NaN              NaN            NaN           NaN
# ...   ...          ...              ...            ...           ...
# 2095  ...   LoanId_293  4/29/2019 14:35            1.0  InvestorId_1
# 2096  ...  LoanId_1040  4/29/2019 14:32            1.0  InvestorId_1
# 2097  ...  LoanId_1585   6/15/2019 6:20            1.0  InvestorId_1
# 2098  ...  LoanId_1314  4/23/2019 15:44            1.0  InvestorId_1
# 2099  ...  LoanId_1570  4/10/2019 17:33            1.0  InvestorId_1
#
#               DueDate       LoanApplicationId       PayBackId  \
# 0                 NaN                     NaN             NaN
# 1                 NaN                     NaN             NaN
# 2                 NaN                     NaN             NaN
# 3                 NaN                     NaN             NaN
# 4                 NaN                     NaN             NaN
# ...               ...                     ...             ...
# 2095  4/29/2019 21:55   LoanApplicationId_524  PayBackId_1106
# 2096  4/29/2019 23:53  LoanApplicationId_1441   PayBackId_966
# 2097   4/30/2019 5:40  LoanApplicationId_1466  PayBackId_1271
# 2098   4/30/2019 9:37  LoanApplicationId_1389   PayBackId_945
# 2099  4/30/2019 12:16    LoanApplicationId_57   PayBackId_830
#
#            ThirdPartyId IsThirdPartyConfirmed  IsDefaulted
# 0                   NaN                   NaN          NaN
# 1                   NaN                   NaN          NaN
# 2                   NaN                   NaN          NaN
# 3                   NaN                   NaN          NaN
# 4                   NaN                   NaN          NaN
# ...                 ...                   ...          ...
# 2095   ThirdPartyId_857                   1.0          0.0
# 2096   ThirdPartyId_958                   1.0          0.0
# 2097  ThirdPartyId_1981                   1.0          0.0
# 2098   ThirdPartyId_705                   1.0          0.0
# 2099   ThirdPartyId_899                   1.0          0.0
#
# [2100 rows x 27 columns]

# %%
c = df_train.columns
c[0]
z = range(0,len(c)-1)

for x,z in zip(c,z):
    print(c[z],len(df_train[x].unique()))
# Out:
# CustomerId 421
# TransactionStartTime 1606
# Value 98
# Amount 77
# TransactionId 1758
# BatchId 1713
# SubscriptionId 6
# CurrencyCode 1
# CountryCode 1
# ProviderId 1
# ProductId 16
# ProductCategory 7
# ChannelId 1
# TransactionStatus 2
# IssuedDateLoan 1102
# AmountLoan 648
# Currency 2
# LoanId 1160
# PaidOnDate 1428
# IsFinalPayBack 3
# InvestorId 4
# DueDate 1102
# LoanApplicationId 1157
# PayBackId 1486
# ThirdPartyId 1482
# IsThirdPartyConfirmed 3

# %%
df_train["Currency"].value_counts()
# Out:
# UGX    1488
# Name: Currency, dtype: int64

# %%
df_train["Currency"].isnull().value_counts()
# Out:
# False    1488
# True      612
# Name: Currency, dtype: int64

# %%
df_train.drop(["CurrencyCode", "CountryCode", "ProviderId", "ChannelId", "TransactionStatus", "Currency"], axis=1, inplace=True)
df_train.drop(["TransactionId", "SubscriptionId", "ThirdPartyId", "InvestorId", "PayBackId"], axis=1, inplace=True)

# %%
df_train.drop(["BatchId","LoanId"],axis=1,inplace=True)

# %%
df_train.drop(["LoanApplicationId"],axis=1,inplace=True)

# %%
df_train
# Out:
#           CustomerId TransactionStartTime   Value  Amount    ProductId  \
# 0      CustomerId_27      9/21/2018 12:17   550.0  -550.0  ProductId_7
# 1      CustomerId_27       9/25/2018 9:20   550.0  -550.0  ProductId_7
# 2      CustomerId_27      9/25/2018 10:33   550.0  -550.0  ProductId_7
# 3      CustomerId_27      9/27/2018 10:26  1000.0 -1000.0  ProductId_7
# 4      CustomerId_27      9/27/2018 12:44   500.0  -500.0  ProductId_7
# ...              ...                  ...     ...     ...          ...
# 2095   CustomerId_28      3/30/2019 21:55  2000.0 -2000.0  ProductId_8
# 2096   CustomerId_28      3/30/2019 23:54  5000.0 -5000.0  ProductId_7
# 2097   CustomerId_34       3/31/2019 5:40  5000.0 -5000.0  ProductId_3
# 2098  CustomerId_346       3/31/2019 9:37  1500.0 -1500.0  ProductId_8
# 2099  CustomerId_188      3/31/2019 12:16  1000.0 -1000.0  ProductId_3
#
#      ProductCategory   IssuedDateLoan  AmountLoan       PaidOnDate  \
# 0            airtime              NaN         NaN              NaN
# 1            airtime              NaN         NaN              NaN
# 2            airtime              NaN         NaN              NaN
# 3            airtime              NaN         NaN              NaN
# 4            airtime              NaN         NaN              NaN
# ...              ...              ...         ...              ...
# 2095    data_bundles  3/30/2019 21:55      2370.0  4/29/2019 14:35
# 2096         airtime  3/30/2019 23:54      5925.0  4/29/2019 14:32
# 2097         airtime   3/31/2019 5:40      7100.0   6/15/2019 6:20
# 2098    data_bundles   3/31/2019 9:37      1733.0  4/23/2019 15:44
# 2099         airtime  3/31/2019 12:16      1090.0  4/10/2019 17:33
#
#       IsFinalPayBack          DueDate  IsThirdPartyConfirmed  IsDefaulted
# 0                NaN              NaN                    NaN          NaN
# 1                NaN              NaN                    NaN          NaN
# 2                NaN              NaN                    NaN          NaN
# 3                NaN              NaN                    NaN          NaN
# 4                NaN              NaN                    NaN          NaN
# ...              ...              ...                    ...          ...
# 2095             1.0  4/29/2019 21:55                    1.0          0.0
# 2096             1.0  4/29/2019 23:53                    1.0          0.0
# 2097             1.0   4/30/2019 5:40                    1.0          0.0
# 2098             1.0   4/30/2019 9:37                    1.0          0.0
# 2099             1.0  4/30/2019 12:16                    1.0          0.0
#
# [2100 rows x 13 columns]

# %%
c = df_train.columns
c[0]
z = range(0,len(c)-1)

for x,z in zip(c,z):
    print(c[z],len(df_train[x].unique()))
# Out:
# CustomerId 421
# TransactionStartTime 1606
# Value 98
# Amount 77
# ProductId 16
# ProductCategory 7
# IssuedDateLoan 1102
# AmountLoan 648
# PaidOnDate 1428
# IsFinalPayBack 3
# DueDate 1102
# LoanApplicationId 1157
# IsThirdPartyConfirmed 3

# %%
df_train["IsFinalPayBack"].value_counts()
# Out:
# 1.0    1089
# 0.0     399
# Name: IsFinalPayBack, dtype: int64

# %%
df_train["IsDefaulted"].value_counts()
# Out:
# 0.0    1310
# 1.0     178
# Name: IsDefaulted, dtype: int64

# %% [markdown]
# On va transformer le dataset pour qu'il soit exploitable on utilisera les variables petit à petit

# %%
df_train = df_train.dropna()

# %%
df = df_train.copy()

# %%
df
# Out:
#           CustomerId TransactionStartTime   Value  Amount    ProductId  \
# 0      CustomerId_27      9/21/2018 12:17   550.0  -550.0  ProductId_7
# 1      CustomerId_27       9/25/2018 9:20   550.0  -550.0  ProductId_7
# 2      CustomerId_27      9/25/2018 10:33   550.0  -550.0  ProductId_7
# 3      CustomerId_27      9/27/2018 10:26  1000.0 -1000.0  ProductId_7
# 4      CustomerId_27      9/27/2018 12:44   500.0  -500.0  ProductId_7
# ...              ...                  ...     ...     ...          ...
# 2095   CustomerId_28      3/30/2019 21:55  2000.0 -2000.0  ProductId_8
# 2096   CustomerId_28      3/30/2019 23:54  5000.0 -5000.0  ProductId_7
# 2097   CustomerId_34       3/31/2019 5:40  5000.0 -5000.0  ProductId_3
# 2098  CustomerId_346       3/31/2019 9:37  1500.0 -1500.0  ProductId_8
# 2099  CustomerId_188      3/31/2019 12:16  1000.0 -1000.0  ProductId_3
#
#      ProductCategory   IssuedDateLoan  AmountLoan       PaidOnDate  \
# 0            airtime              NaN         NaN              NaN
# 1            airtime              NaN         NaN              NaN
# 2            airtime              NaN         NaN              NaN
# 3            airtime              NaN         NaN              NaN
# 4            airtime              NaN         NaN              NaN
# ...              ...              ...         ...              ...
# 2095    data_bundles  3/30/2019 21:55      2370.0  4/29/2019 14:35
# 2096         airtime  3/30/2019 23:54      5925.0  4/29/2019 14:32
# 2097         airtime   3/31/2019 5:40      7100.0   6/15/2019 6:20
# 2098    data_bundles   3/31/2019 9:37      1733.0  4/23/2019 15:44
# 2099         airtime  3/31/2019 12:16      1090.0  4/10/2019 17:33
#
#       IsFinalPayBack          DueDate  IsThirdPartyConfirmed  IsDefaulted
# 0                NaN              NaN                    NaN          NaN
# 1                NaN              NaN                    NaN          NaN
# 2                NaN              NaN                    NaN          NaN
# 3                NaN              NaN                    NaN          NaN
# 4                NaN              NaN                    NaN          NaN
# ...              ...              ...                    ...          ...
# 2095             1.0  4/29/2019 21:55                    1.0          0.0
# 2096             1.0  4/29/2019 23:53                    1.0          0.0
# 2097             1.0   4/30/2019 5:40                    1.0          0.0
# 2098             1.0   4/30/2019 9:37                    1.0          0.0
# 2099             1.0  4/30/2019 12:16                    1.0          0.0
#
# [2100 rows x 13 columns]

# %%
df.drop(["TransactionStartTime", "IssuedDateLoan", "PaidOnDate", "DueDate"], axis=1, inplace=True)

# %%
df
# Out:
#           CustomerId   Value  Amount    ProductId ProductCategory  AmountLoan  \
# 0      CustomerId_27   550.0  -550.0  ProductId_7         airtime         NaN
# 1      CustomerId_27   550.0  -550.0  ProductId_7         airtime         NaN
# 2      CustomerId_27   550.0  -550.0  ProductId_7         airtime         NaN
# 3      CustomerId_27  1000.0 -1000.0  ProductId_7         airtime         NaN
# 4      CustomerId_27   500.0  -500.0  ProductId_7         airtime         NaN
# ...              ...     ...     ...          ...             ...         ...
# 2095   CustomerId_28  2000.0 -2000.0  ProductId_8    data_bundles      2370.0
# 2096   CustomerId_28  5000.0 -5000.0  ProductId_7         airtime      5925.0
# 2097   CustomerId_34  5000.0 -5000.0  ProductId_3         airtime      7100.0
# 2098  CustomerId_346  1500.0 -1500.0  ProductId_8    data_bundles      1733.0
# 2099  CustomerId_188  1000.0 -1000.0  ProductId_3         airtime      1090.0
#
#       IsFinalPayBack  IsThirdPartyConfirmed  IsDefaulted
# 0                NaN                    NaN          NaN
# 1                NaN                    NaN          NaN
# 2                NaN                    NaN          NaN
# 3                NaN                    NaN          NaN
# 4                NaN                    NaN          NaN
# ...              ...                    ...          ...
# 2095             1.0                    1.0          0.0
# 2096             1.0                    1.0          0.0
# 2097             1.0                    1.0          0.0
# 2098             1.0                    1.0          0.0
# 2099             1.0                    1.0          0.0
#
# [2100 rows x 9 columns]

# %%
# Out:
# Index(['CustomerId_390', 'CustomerId_369', 'CustomerId_233', 'CustomerId_399',
#        'CustomerId_326', 'CustomerId_310', 'CustomerId_27', 'CustomerId_237',
#        'CustomerId_261', 'CustomerId_329',
#        ...
#        'CustomerId_141', 'CustomerId_94', 'CustomerId_132', 'CustomerId_266',
#        'CustomerId_397', 'CustomerId_46', 'CustomerId_6', 'CustomerId_224',
#        'CustomerId_370', 'CustomerId_92'],
#       dtype='object', length=421)

# %%
emprunt = [df.CustomerId.value_counts()]

# %%
emprunt
# Out:
# [CustomerId_390    100
#  CustomerId_369     53
#  CustomerId_233     42
#  CustomerId_399     40
#  CustomerId_326     30
#                   ...
#  CustomerId_46       1
#  CustomerId_6        1
#  CustomerId_224      1
#  CustomerId_370      1
#  CustomerId_92       1
#  Name: CustomerId, Length: 421, dtype: int64]

# %%
df["CustomerId"].isin(emprunt.index)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 2095    True
# 2096    True
# 2097    True
# 2098    True
# 2099    True
# Name: CustomerId, Length: 2100, dtype: bool

# %%
for i in range(len(df.CustomerId)):
    if df["CustomerId"][i] == emprunt.index:
        df["nbemprunt"] = emprunt.value

# %%
df
# Out:
#           CustomerId   Value  Amount    ProductId ProductCategory  AmountLoan  \
# 0      CustomerId_27   550.0  -550.0  ProductId_7         airtime         NaN
# 1      CustomerId_27   550.0  -550.0  ProductId_7         airtime         NaN
# 2      CustomerId_27   550.0  -550.0  ProductId_7         airtime         NaN
# 3      CustomerId_27  1000.0 -1000.0  ProductId_7         airtime         NaN
# 4      CustomerId_27   500.0  -500.0  ProductId_7         airtime         NaN
# ...              ...     ...     ...          ...             ...         ...
# 2095   CustomerId_28  2000.0 -2000.0  ProductId_8    data_bundles      2370.0
# 2096   CustomerId_28  5000.0 -5000.0  ProductId_7         airtime      5925.0
# 2097   CustomerId_34  5000.0 -5000.0  ProductId_3         airtime      7100.0
# 2098  CustomerId_346  1500.0 -1500.0  ProductId_8    data_bundles      1733.0
# 2099  CustomerId_188  1000.0 -1000.0  ProductId_3         airtime      1090.0
#
#       IsFinalPayBack  IsThirdPartyConfirmed  IsDefaulted nbemprunt
# 0                NaN                    NaN          NaN       NaN
# 1                NaN                    NaN          NaN       NaN
# 2                NaN                    NaN          NaN       NaN
# 3                NaN                    NaN          NaN       NaN
# 4                NaN                    NaN          NaN       NaN
# ...              ...                    ...          ...       ...
# 2095             1.0                    1.0          0.0       NaN
# 2096             1.0                    1.0          0.0       NaN
# 2097             1.0                    1.0          0.0       NaN
# 2098             1.0                    1.0          0.0       NaN
# 2099             1.0                    1.0          0.0       NaN
#
# [2100 rows x 10 columns]

# %%
df_demise = pd.get_dummies(df)

# %%
df_demise.columns
# Out:
# Index(['Value', 'Amount', 'AmountLoan', 'IsFinalPayBack',
#        'IsThirdPartyConfirmed', 'IsDefaulted', 'ProductId_ProductId_1',
#        'ProductId_ProductId_10', 'ProductId_ProductId_13',
#        'ProductId_ProductId_15', 'ProductId_ProductId_16',
#        'ProductId_ProductId_17', 'ProductId_ProductId_18',
#        'ProductId_ProductId_2', 'ProductId_ProductId_3',
#        'ProductId_ProductId_4', 'ProductId_ProductId_5',
#        'ProductId_ProductId_6', 'ProductId_ProductId_7',
#        'ProductId_ProductId_8', 'ProductId_ProductId_9',
#        'ProductCategory_airtime', 'ProductCategory_data_bundles',
#        'ProductCategory_financial_services', 'ProductCategory_movies',
#        'ProductCategory_retail', 'ProductCategory_tv',
#        'ProductCategory_utility_bill'],
#       dtype='object')

# %%
df_demise
# Out:
#         Value   Amount  AmountLoan  IsFinalPayBack  IsThirdPartyConfirmed  \
# 9     10000.0 -10000.0     10016.0             1.0                    0.0
# 10    10000.0 -10000.0       584.0             1.0                    0.0
# 11    10000.0 -10000.0       100.0             1.0                    0.0
# 13     5150.0  -5150.0      5614.0             1.0                    0.0
# 14      515.0   -515.0       544.0             1.0                    0.0
# ...       ...      ...         ...             ...                    ...
# 2095   2000.0  -2000.0      2370.0             1.0                    1.0
# 2096   5000.0  -5000.0      5925.0             1.0                    1.0
# 2097   5000.0  -5000.0      7100.0             1.0                    1.0
# 2098   1500.0  -1500.0      1733.0             1.0                    1.0
# 2099   1000.0  -1000.0      1090.0             1.0                    1.0
#
#       IsDefaulted  ProductId_ProductId_1  ProductId_ProductId_10  \
# 9             0.0                      0                       0
# 10            0.0                      0                       0
# 11            0.0                      0                       0
# 13            0.0                      0                       0
# 14            0.0                      0                       0
# ...           ...                    ...                     ...
# 2095          0.0                      0                       0
# 2096          0.0                      0                       0
# 2097          0.0                      0                       0
# 2098          0.0                      0                       0
# 2099          0.0                      0                       0
#
#       ProductId_ProductId_13  ProductId_ProductId_15  ...  \
# 9                          0                       0  ...
# 10                         0                       0  ...
# 11                         0                       0  ...
# 13                         0                       0  ...
# 14                         0                       0  ...
# ...                      ...                     ...  ...
# 2095                       0                       0  ...
# 2096                       0                       0  ...
# 2097                       0                       0  ...
# 2098                       0                       0  ...
# 2099                       0                       0  ...
#
#       ProductId_ProductId_7  ProductId_ProductId_8  ProductId_ProductId_9  \
# 9                         1                      0                      0
# 10                        1                      0                      0
# 11                        1                      0                      0
# 13                        1                      0                      0
# 14                        1                      0                      0
# ...                     ...                    ...                    ...
# 2095                      0                      1                      0
# 2096                      1                      0                      0
# 2097                      0                      0                      0
# 2098                      0                      1                      0
# 2099                      0                      0                      0
#
#       ProductCategory_airtime  ProductCategory_data_bundles  \
# 9                           1                             0
# 10                          1                             0
# 11                          1                             0
# 13                          1                             0
# 14                          1                             0
# ...                       ...                           ...
# 2095                        0                             1
# 2096                        1                             0
# 2097                        1                             0
# 2098                        0                             1
# 2099                        1                             0
#
#       ProductCategory_financial_services  ProductCategory_movies  \
# 9                                      0                       0
# 10                                     0                       0
# 11                                     0                       0
# 13                                     0                       0
# 14                                     0                       0
# ...                                  ...                     ...
# 2095                                   0                       0
# 2096                                   0                       0
# 2097                                   0                       0
# 2098                                   0                       0
# 2099                                   0                       0
#
#       ProductCategory_retail  ProductCategory_tv  ProductCategory_utility_bill
# 9                          0                   0                             0
# 10                         0                   0                             0
# 11                         0                   0                             0
# 13                         0                   0                             0
# 14                         0                   0                             0
# ...                      ...                 ...                           ...
# 2095                       0                   0                             0
# 2096                       0                   0                             0
# 2097                       0                   0                             0
# 2098                       0                   0                             0
# 2099                       0                   0                             0
#
# [1486 rows x 28 columns]

# %%
X = df_demise.drop("IsDefaulted", axis=1)
y = df_demise["IsDefaulted"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
dtree = tree.DecisionTreeClassifier(criterion = 'gini', random_state = 0)
dtr=dtree.fit(X_train, y_train)
dtrpred = dtree.predict(X_test)
print(classification_report(y_test,dtrpred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.95       258
#          1.0       0.65      0.70      0.67        40
#
#     accuracy                           0.91       298
#    macro avg       0.80      0.82      0.81       298
# weighted avg       0.91      0.91      0.91       298

# %%
pd.DataFrame(dtree.feature_importances_, index=X_train.columns).plot.bar(figsize=(12,8))

# %%
N, train_score,val_score = learning_curve(dtree, X_train, y_train, cv = 4, train_sizes = np.linspace(0.1,1,10), scoring = 'f1')
plt.figure(figsize=(12,8))
plt.plot(N, train_score.mean(axis=1),label='train_score')
plt.plot(N, val_score.mean(axis=1),label='val_score')
plt.legend()

# %%
random_forest_classifier = make_pipeline(SelectKBest(f_classif,k=10),RandomForestClassifier())
random_forest_classifier.fit(X_train,y_train)
y_pred_rfc = random_forest_classifier.predict(X_test)
print(classification_report(y_test,y_pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.95      0.97       258
#          1.0       0.73      0.95      0.83        40
#
#     accuracy                           0.95       298
#    macro avg       0.86      0.95      0.90       298
# weighted avg       0.96      0.95      0.95       298

# %%
#pd.DataFrame(random_forest_classifier.feature_importances_, index=X_train.columns).plot.bar(figsize=(12,8))

# %%
N, train_score,val_score = learning_curve(random_forest_classifier, X_train, y_train, cv = 4, train_sizes = np.linspace(0.1,1,10), scoring = 'f1')
plt.figure(figsize=(12,8))
plt.plot(N, train_score.mean(axis=1),label='train_score')
plt.plot(N, val_score.mean(axis=1),label='val_score')
plt.legend()
